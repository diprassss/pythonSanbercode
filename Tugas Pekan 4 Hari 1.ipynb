# %% [markdown]
# # Soal 1. Menentukan jenis data categorical atau numeric
# Jelaskan data kategorikal (kualitatif) dan data numerik (kuantitatif)

# %% [markdown]
# Jawab disini:

# %% [markdown]
# - Data kategorikal = adalah Data kategorikal merupakan data yang mencerminkan karakteristik seperti bahasa, jenis kelamin seseorang, warna rambut seseorang, atau nilai numerik bulat yang tidak memiliki makna matematis. Contoh : 1 untuk laki-laki dan 0 untuk perempuan. Data kategorikal tersebut kemudian terbagi atas dua jenis: Nominal dan Ordinal
#     1. Data Nominal =  merupakan data yang tidak memiliki order dan berbentuk label tanpa adanya tingkatan perangkingan. Contoh : Jenis kelamin, warna, dsb
#     2. Data ordinal =  merupakan data kategorikal yang disusun dalam sebuah order dan diatur menggunakan peringkat-peringkat tertentu. Contohnya adalah status ekonomi, huruf mutu, level pendidikan, dsb
#
# - Data numerik = Data numerik terbagi menjadi 2, yaitu kontinyu dan diskrit.
#     1. Variabel diskrit merupakan data yang memiliki nilai yang terbata. Contoh : jumlah medali yang dimenangkan oleh para atlet.
#     2. Variabel kontinu merupakan jenis data yang berbeda dengan data kategorikal. Data kontinu merupakan data kuantitatif yang dapat diukur, dapat memiliki nilai yang sangat tinggi (infinite). Contoh : Massa bayi, Kecepatan angin, Temperatur, Usia
#     - Selain contoh diatas, terdapat 2 tipe data yang masuk ke dalam kategori data kontinyu yaitu data interval dan rasio.
#         1.  Data interval merupakan skala dimana dua buah nilai memiliki makna tertentu. Beberapa karakteristik dari data interval adalah sebagai berikut:
#             - Pengukuran: data tersebut diukur menggunakan skala interval. Contohnya adalah penggunaan penggaris dimana untuk setiap interval terkecil penanda pertama mengukur jarak temperatur yang sama persis dengan interval terkecil penanda yang lain.
#             - Perbedaan interval: pengukuran untuk setiap nilai dari interval data sama persis. Contohnya adalah perbedaan interval antara 10 cm dan 20 cm adalah sama dengan 20 cm dan 30 cm
#             - Kalkulasi: Dalam data interval, seseorang dapat menambah-kurangkan angka pada data tersebut, tetapi tidak bisa membagi atau mengalikan data tersebut dengan suatu nilai.
#             - Titik nol: Titik nol dalam data interval dapat berubah-ubah. Contohnya adalah temperatur dapat bernilai negatif
#         2. Data rasio merupakan data yang terdefinisi pada data kuantitatif yang memiliki sifat-sifat yang sama dengan data interval. Data rasio memiliki sifat-sifat yang sama dengan data interval. Namun, data rasio memiliki nilai 0 yang absolut. Contoh : pengukuran tinggi badan. Tinggi badan seseorang tidak dapat bernilai negatif (misal -70 cm). Pun halnya dengan massa seseorang yang tidak dapat bernilai negatif (-29 kg).

# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=19Yc404D3U3OPPoUP8J1pXETlTmA4hOOX)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('austin_weather.csv')
df.head()
# Out:
#          Date  TempHighF TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  12/21/2013         74       60        45            67           49
# 1  12/22/2013         56       48        39            43           36
# 2  12/23/2013         58       45        32            31           27
# 3  12/24/2013         61       46        31            36           28
# 4  12/25/2013         58       50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   object
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
#  13  VisibilityHighMiles         1319 non-null   object
#  14  VisibilityAvgMiles          1319 non-null   object
#  15  VisibilityLowMiles          1319 non-null   object
#  16  WindHighMPH                 1319 non-null   object
#  17  WindAvgMPH                  1319 non-null   object
#  18  WindGustMPH                 1319 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: int64(2), object(19)
# memory usage: 216.5+ KB

# %%
df = df.sample(1000)

# %% [markdown]
# <h2>Soal 2. Visualisasi Scatter Plot dengan memiliki missing value </h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' dan 'na' yang dianggap sebagai missing value,  namun data ini tidak bisa di ubah ke bentuk float, maka ubahlah data tersebut menjadi NaN dengan menambahkan argumen na_values=['na', '-'] saat menggunakan atribut pd.read_csv('nama file.csv'. na_values=..]
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# a. Buahlah visualisasi scatter plot menggunakan sample(1000), sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# b. Kemudian bandingkan data visualisasi diatas dengan visualisasi data (sample=1000) setelah handling missing value menggunakan:
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html

# %% [markdown]
# #                     **Expected output**
#
# #                     **Tanpa Handling missing value**
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1FYJkCwAfm8f3jyNdzOnCvp15hS_DixHr)
#
# ##                    **Dengan Handling missing value**
# ![dengan handling missing value](https://drive.google.com/uc?id=1nqZuPdBsqSsOud-_XuBGujDAcJWEEvIr)

# %%
# read na values and convert to float
df = pd.read_csv('austin_weather.csv', na_values=['na', '-'])
df = df.astype({'DewPointAvgF':'float' , 'HumidityAvgPercent':'float', 'WindAvgMPH':'float'})
df.isnull().sum()
# Out:
# Date                           0
# TempHighF                      0
# TempAvgF                       7
# TempLowF                       0
# DewPointHighF                  7
# DewPointAvgF                  11
# DewPointLowF                   7
# HumidityHighPercent            2
# HumidityAvgPercent            10
# HumidityLowPercent             2
# SeaLevelPressureHighInches     3
# SeaLevelPressureAvgInches      3
# SeaLevelPressureLowInches      3
# VisibilityHighMiles           12
# VisibilityAvgMiles            12
# VisibilityLowMiles            12
# WindHighMPH                    2
# WindAvgMPH                    13
# WindGustMPH                    4
# PrecipitationSumInches         0
# Events                         0
# dtype: int64

# %%
# set x, y, color, sizes
x = df['HumidityAvgPercent'].sample(n=1000, random_state=1)
y = df['DewPointAvgF'].sample(n=1000, random_state=1)
colors = df['TempAvgF'].sample(n=1000, random_state=1)
sizes = df['WindAvgMPH'].sample(n=1000, random_state=1) * 20

# %%
# scatter plot
plt.figure(figsize=(12,8))
plt.scatter(x, y, s=sizes, c=colors, cmap='coolwarm')
plt.xlabel('Humadity Average (%)')
plt.ylabel('Dew Point Average (F)')
plt.title('Austin Weather')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = df.fillna({'DewPointAvgF':'ffill' , 'HumidityAvgPercent':'ffill', 'WindAvgMPH':'ffill'})
df.isnull().sum()
# Out:
# Date                           0
# TempHighF                      0
# TempAvgF                       7
# TempLowF                       0
# DewPointHighF                  7
# DewPointAvgF                   0
# DewPointLowF                   7
# HumidityHighPercent            2
# HumidityAvgPercent             0
# HumidityLowPercent             2
# SeaLevelPressureHighInches     3
# SeaLevelPressureAvgInches      3
# SeaLevelPressureLowInches      3
# VisibilityHighMiles           12
# VisibilityAvgMiles            12
# VisibilityLowMiles            12
# WindHighMPH                    2
# WindAvgMPH                     0
# WindGustMPH                    4
# PrecipitationSumInches         0
# Events                         0
# dtype: int64

# %%
# scatter plot
plt.figure(figsize=(12,8))
plt.scatter(x, y, s=sizes, c=colors, cmap='coolwarm')
plt.xlabel('Humadity Average (%)')
plt.ylabel('Dew Point Average (F)')
plt.title('Austin Weather')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analisa :
#
# Data yang belum di handling memiliki 0 missing value di setiap kolomnya karena data ['na', '-'] tidak terbaca sebagai missing value
# dan merubah beberapa kolom menjadi float
#
# setelah di handling dengan metode pandas, data missing value terlihat di beberapa kolom terutama pada kolom :
#
# DewPointAvgF = 11, HumidityAvgPercent = 10, WindAvgMPH = 13
#
# dan melakukan proses ploting scatter dgn sampel (1000)
#
# kemudian data di proses dengan method fillna 'ffill' dan bisa dibandingkan bahwa data yang telah di lakukan proses fillna 'ffill' memiliki 0 missing value di setiap kolomnya, hal ini tentu berpengaruh pada ploting data

# %% [markdown]
# Download [price.csv](https://drive.google.com/uc?export=download&id=1LfuQmLb8AZxAvJzgWJ3u4h49EoTGqO-R)

# %%
df2 = pd.read_csv('price.csv')
df2.head()
# Out:
#    Observation  Dist_Taxi  Dist_Market  Dist_Hospital  Carpet  Builtup  \
# 0            1     9796.0       5250.0        10703.0  1659.0   1961.0
# 1            2     8294.0       8186.0        12694.0  1461.0   1752.0
# 2            3    11001.0      14399.0        16991.0  1340.0   1609.0
# 3            4     8301.0      11188.0        12289.0  1451.0   1748.0
# 4            5    10510.0      12629.0        13921.0  1770.0   2111.0
#
#         Parking City_Category  Rainfall  House_Price
# 0          Open         CAT B       530      6649000
# 1  Not Provided         CAT B       210      3982000
# 2  Not Provided         CAT A       720      5401000
# 3       Covered         CAT B       620      5373000
# 4  Not Provided         CAT B       450      4662000

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3. Visualisasi Data with Handling outliers </h2>
#
# Pada tugas kali ini, kita akan melakukan handling outliers. Outliers ditemukan pada kolom 'House_Price' dengan menggunakan boxplot dari library seaborn seperti gambar berikut:
#
#
# ![boxplot1](https://drive.google.com/uc?id=1y2jRwf8zRPXQtSBkmjJLcqUm4l6DR7d9)
#
#
# Dengan menggunakan Interquartile range, kita bisa temukan nilai data outliers dan meremove data outlier tersebut.
#
# *   Tentukan nilai batas atas dan batas bawah dari Interquartile range tersebut
# *   Remove data outliers tersebut menggunakan batas atas dan batas bawah
# *   Visualisasikan hasil data yang sudah d remove outliers seperti expected berikut:

# %% [markdown]
# **EXPECTED OUTPUT:**
#
# Batas bawah & batas atas:
#
# 871625.0 10976625.0
#
# Visualisasi boxplot:
#
# ![boxplot2](https://drive.google.com/uc?id=1qZc-lEa5FUzSQ_cyt4_GJQ0TZ8c6WjHX)

# %%
# boxplot 'House_Price'
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(data=df2, x='House_Price')
# Out:
# <AxesSubplot:xlabel='House_Price'>

# %%
# handling outlier
q1 = df2['House_Price'].quantile(0.25)
q3 = df2['House_Price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5*iqr)
upper_bound = q3 + (1.5*iqr)
print(lower_bound, upper_bound)
# Out:
# 871625.0 10976625.0

# %%
# filtering data outlier
df2['House_Price'] = df2[(df2['House_Price']>lower_bound) & (df2['House_Price']<upper_bound)]
df2['House_Price']
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 931    932.0
# 932    933.0
# 933    934.0
# 934    935.0
# 935    936.0
# Name: House_Price, Length: 936, dtype: object

# %%
# boxplot after handling outlier
plt.figure(figsize=(12,8))
sns.boxplot(data=df2, x='House_Price')
# Out:
# <AxesSubplot:xlabel='House_Price'>
